# %% [markdown]
# # E-retail factors for customer activation and retention: A case study from Indian e-commerce customers

# %% [markdown]
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %%
import pandas as pd

# %%
df=pd.read_excel('customer_retention_dataset.xlsx')
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# # Encoding DataFrame

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
#      1Gender of respondent  2 How old are you?   \
# 0                        1                    1
# 1                        0                    0
# 2                        0                    0
# 3                        1                    0
# 4                        0                    0
# ..                     ...                  ...
# 264                      0                    0
# 265                      0                    1
# 266                      0                    2
# 267                      0                    4
# 268                      0                    2
#
#      3 Which city do you shop online from?  \
# 0                                        2
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.iloc[:,:10].isnull().sum()
# Out:
# 1Gender of respondent                                                                                     0
# 2 How old are you?                                                                                        0
# 3 Which city do you shop online from?                                                                     0
# 4 What is the Pin Code of where you shop online from?                                                     0
# 5 Since How Long You are Shopping Online ?                                                                0
# 6 How many times you have made an online purchase in the past 1 year?                                     0
# 7 How do you access the internet while shopping on-line?                                                  0
# 8 Which device do you use to access the online shopping?                                                  0
# 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                              0
# ...

# %%
df.iloc[:,10:20].isnull().sum()
# Out:
# 11 What browser do you run on your device to access the website?\t\t\t                                                                                                                                                 0
# 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                                                                            0
# 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                                                                                                                0
# 14 How much time do you explore the e- retail store before making a purchase decision?                                                                                                                                 0
# ...

# %%
df.iloc[:,20:30].isnull().sum()
# Out:
# 21 All relevant information on listed products must be stated clearly                                         0
# 22 Ease of navigation in website                                                                              0
# 23 Loading and processing speed                                                                               0
# 24 User friendly Interface of the website                                                                     0
# 25 Convenient Payment methods                                                                                 0
# 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time         0
# 27 Empathy (readiness to assist with queries) towards the customers                                           0
# 28 Being able to guarantee the privacy of the customer                                                        0
# ...

# %%
df.iloc[:,30:40].isnull().sum()
# Out:
# 31 Enjoyment is derived from shopping online                                           0
# 32 Shopping online is convenient and flexible                                          0
# 33 Return and replacement policy of the e-tailer is important for purchase decision    0
# 34 Gaining access to loyalty programs is a benefit of shopping online                  0
# 35 Displaying quality Information on the website improves satisfaction of customers    0
# 36 User derive satisfaction while shopping on a good quality website or application    0
# 37 Net Benefit derived from shopping online can lead to users satisfaction             0
# 38 User satisfaction cannot exist without trust                                        0
# 39 Offering a wide variety of listed product in several category                       0
# 40 Provision of complete and relevant product information                              0
# dtype: int64

# %%
df.iloc[:,40:50].isnull().sum()
# Out:
# 41 Monetary savings                                                                                                                                                0
# 42 The Convenience of patronizing the online retailer                                                                                                              0
# 43 Shopping on the website gives you the sense of adventure                                                                                                        0
# 44 Shopping on your preferred e-tailer enhances your social status                                                                                                 0
# 45 You feel gratification shopping on your favorite e-tailer                                                                                                       0
# ...

# %%
df.iloc[:,50:60].isnull().sum()
# Out:
# Wild variety of product on offer                          0
# Complete, relevant description information of products    0
# Fast loading website speed of website and application     0
# Reliability of the website or application                 0
# Quickness to complete purchase                            0
# Availability of several payment options                   0
# Speedy order delivery                                     0
# Privacy of customers’ information                         0
# Security of customer financial information                0
# Perceived Trustworthiness                                 0
# dtype: int64

# %%
df.iloc[:,60:72].isnull().sum()
# Out:
# Presence of online assistance through multi-channel                        0
# Longer time to get logged in (promotion, sales period)                     0
# Longer time in displaying graphics and photos (promotion, sales period)    0
# Late declaration of price (promotion, sales period)                        0
# Longer page loading time (promotion, sales period)                         0
# Limited mode of payment on most products (promotion, sales period)         0
# Longer delivery period                                                     0
# Change in website/Application design                                       0
# Frequent disruption when moving from one page to another                   0
# Website is as efficient as before                                          0
# Which of the Indian online retailer would you recommend to a friend?       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   int64
# 2 How old are you?                                                      int64
# 3 Which city do you shop online from?                                   int64
# 4 What is the Pin Code of where you shop online from?                   int64
# 5 Since How Long You are Shopping Online ?                              int64
#                                                                         ...
# Longer delivery period                                                  int64
# Change in website/Application design                                    int64
# Frequent disruption when moving from one page to another                int64
# Website is as efficient as before                                       int64
# Which of the Indian online retailer would you recommend to a friend?    int64
# Length: 71, dtype: object

# %%
df.columns=['Gender','Age','City','Pincode','Shopping years','Online purchase in the past 1 year',

            'Internet access','Access device','Screen size of your mobile device','OS of device',

            'Browser','Channel','Medium of next visit','Explore time','Preferred payment option',

            'Abandon frequency','Abandon reason','Easy to read and understand content',

            'Information on similar product','Complete information on listed seller and product',

            'All relevant information on listed products','Ease of navigation in website',

            'Loading and processing speed','User friendly Interface','Convenient Payment methods',

            'Trust for stipulated time','Empathy','Customer privacy gurantee',

            'Responsiveness/availability of communication channels','Monetary benefit and discounts',

            'Enjoyment derived','Convenience/flexiblility','Return and replacement policy',

            'Access to loyalty programs','Display of quality information','Satisfaction',

            'Net Benefit','Trust','Wide variety of listed product',

            'Complete and relevant product information','Monetary savings',

            'Convenience of patronizing','Sense of adventure','Enhancement of social status',

            'Gratification','Fulfillment of certain roles','Value for money spent',''

            'Online retailers customer shopped from','Easy to use website/application',

            'visual appeal', 'Wild variety of product on offer',

            'Complete, relevant description information of products','Loading time',

            'Reliability', 'Quickness to complete purchase',

            'Availability of several payment options','Speedy order delivery ',

            'Privacy of customers’ information', 'Security of customer financial information',

            'Perceived Trustworthiness','Presence of online assistance through multi-channel',

            'Longer time to get logged in','Longer time in displaying graphics and photos',

            'Late declaration of price','Longer page loading time',

            'Limited mode of payment on most products','Longer delivery period',

            'Change in website/Application design',

            'Frequent disruption when moving from one page to another',

            'Website efficiency','Recommended online retailer']

# %% [markdown]
# # Visualization of Dataset

# %%
import seaborn as sns

# %%
df
# Out:
#      Gender  Age  City  Pincode  Shopping years  \
# 0         1    1     2   110009               3
# 1         0    0     2   110030               3
# 2         0    0     4   201308               2
# 3         1    0     6   132001               2
# 4         0    0     0   530068               1
# ..      ...  ...   ...      ...             ...
# 264       0    0    10   173212               0
# 265       0    1     3   201008               0
# 266       0    2     0   560010               1
# 267       0    4    10   173229               1
# 268       0    2     3   201009               1
#
#      Online purchase in the past 1 year  Internet access  Access device  \
# 0                                     2                0              0
# 1                                     3                3              2
# 2                                     3                1              2
# 3                                     5                1              2
# ...

# %%
sns.countplot(x='Gender',data=df)
print(df['Gender'].value_counts())
# Out:
# 0    181
# 1     88
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Age',data=df)
print(df['Age'].value_counts())
# Out:
# 1    81
# 0    79
# 2    70
# 4    20
# 3    19
# Name: Age, dtype: int64

# %%
sns.countplot(x='City',data=df)
print(df['City'].value_counts())
# Out:
# 2     58
# 4     43
# 9     40
# 0     37
# 6     27
# 10    18
# 3     18
# 5     12
# 7      9
# 8      5
# 1      2
# Name: City, dtype: int64

# %%
sns.countplot(x='Pincode',data=df)
print(df['Pincode'].value_counts())
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173212     9
# 250001     9
# 173229     9
# 560037     8
# 132036     8
# 560010     8
# 122018     8
# 110011     7
# 201306     7
# 110008     7
# 110014     6
# 110018     6
# 244001     5
# 201312     5
# 530068     5
# 201305     5
# 201009     5
# 201008     5
# 201005     4
# 201001     4
# 201304     4
# 110039     4
# 110030     4
# 110009     4
# 560018     4
# 560003     4
# 122009     4
# 560002     4
# 110042     4
# 201303     4
# 560013     3
# 203001     2
# 560001     1
# 203207     1
# 203202     1
# Name: Pincode, dtype: int64

# %%
sns.countplot(x='Shopping years',data=df)
print(df['Shopping years'].value_counts())
# Out:
# 3    98
# 1    65
# 2    47
# 4    43
# 0    16
# Name: Shopping years, dtype: int64

# %%
sns.countplot(x='Online purchase in the past 1 year',data=df)
print(df['Online purchase in the past 1 year'].value_counts())
# Out:
# 5    114
# 2     63
# 3     47
# 0     29
# 1     10
# 4      6
# Name: Online purchase in the past 1 year, dtype: int64

# %%
sns.countplot(x='Internet access',data=df)
print(df['Internet access'].value_counts())
# Out:
# 2    142
# 3     76
# 1     47
# 0      4
# Name: Internet access, dtype: int64

# %%
sns.countplot(x='Access device',data=df)
print(df['Access device'].value_counts())
# Out:
# 2    141
# 1     86
# 0     30
# 3     12
# Name: Access device, dtype: int64

# %%
sns.countplot(x='Screen size of your mobile device',data=df)
print(df['Screen size of your mobile device'].value_counts())
# Out:
# 3    134
# 2     99
# 0     29
# 1      7
# Name: Screen size of your mobile device, dtype: int64

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Pincode', 'Shopping years',
#        'Online purchase in the past 1 year', 'Internet access',
#        'Access device', 'Screen size of your mobile device', 'OS of device',
#        'Browser', 'Channel', 'Medium of next visit', 'Explore time',
#        'Preferred payment option', 'Abandon frequency', 'Abandon reason',
#        'Easy to read and understand content', 'Information on similar product',
#        'Complete information on listed seller and product',
#        'All relevant information on listed products',
#        'Ease of navigation in website', 'Loading and processing speed',
#        'User friendly Interface', 'Convenient Payment methods',
#        'Trust for stipulated time', 'Empathy', 'Customer privacy gurantee',
#        'Responsiveness/availability of communication channels',
#        'Monetary benefit and discounts', 'Enjoyment derived',
#        'Convenience/flexiblility', 'Return and replacement policy',
# ...

# %%
sns.countplot(x='OS of device',data=df)
print(df['OS of device'].value_counts())
# Out:
# 2    122
# 0     85
# 1     62
# Name: OS of device, dtype: int64

# %%
sns.countplot(x='Browser',data=df)
print(df['Browser'].value_counts())
# Out:
# 0    216
# 3     40
# 2      8
# 1      5
# Name: Browser, dtype: int64

# %%
sns.countplot(x='Channel',data=df)
print(df['Channel'].value_counts())
# Out:
# 2    230
# 0     20
# 1     19
# Name: Channel, dtype: int64

# %%
sns.countplot(x='Medium of next visit',data=df)
print(df['Medium of next visit'].value_counts())
# Out:
# 2    87
# 4    86
# 0    70
# 1    18
# 3     8
# Name: Medium of next visit, dtype: int64

# %%
sns.countplot(x='Explore time',data=df)
print(df['Explore time'].value_counts())
# Out:
# 4    123
# 2     71
# 1     46
# 3     15
# 0     14
# Name: Explore time, dtype: int64

# %%
sns.countplot(x='Preferred payment option',data=df)
print(df['Preferred payment option'].value_counts())
# Out:
# 1    148
# 0     76
# 2     45
# Name: Preferred payment option, dtype: int64

# %%
sns.countplot(x='Abandon frequency',data=df)
print(df['Abandon frequency'].value_counts())
# Out:
# 2    171
# 1     48
# 0     35
# 3     15
# Name: Abandon frequency, dtype: int64

# %%
sns.countplot(x='Abandon reason',data=df)
print(df['Abandon reason'].value_counts())
# Out:
# 0    133
# 4     54
# 1     37
# 2     31
# 3     14
# Name: Abandon reason, dtype: int64

# %%
sns.countplot(x='Easy to read and understand content',data=df)
print(df['Easy to read and understand content'].value_counts())
# Out:
# 2    164
# 0     80
# 3     18
# 1      7
# Name: Easy to read and understand content, dtype: int64

# %%
sns.countplot(x='Information on similar product',data=df)
print(df['Information on similar product'].value_counts())
# Out:
# 3    116
# 0     92
# 2     43
# 1     18
# Name: Information on similar product, dtype: int64

# %%
sns.countplot(x='Complete information on listed seller and product',data=df)
print(df['Complete information on listed seller and product'].value_counts())
# Out:
# 0    101
# 3     87
# 2     52
# 1     18
# 4     11
# Name: Complete information on listed seller and product, dtype: int64

# %%
sns.countplot(x='All relevant information on listed products',data=df)
print(df['All relevant information on listed products'].value_counts())
# Out:
# 0    132
# 2    107
# 3     18
# 1     12
# Name: All relevant information on listed products, dtype: int64

# %%
sns.countplot(x='Ease of navigation in website',data=df)
print(df['Ease of navigation in website'].value_counts())
# Out:
# 2    141
# 0    105
# 3     18
# 1      5
# Name: Ease of navigation in website, dtype: int64

# %%
sns.countplot(x='Loading and processing speed',data=df)
print(df['Loading and processing speed'].value_counts())
# Out:
# 3    115
# 0    112
# 1     18
# 4     12
# 2     12
# Name: Loading and processing speed, dtype: int64

# %%
sns.countplot(x='User friendly Interface',data=df)
print(df['User friendly Interface'].value_counts())
# Out:
# 3    189
# 0     45
# 4     18
# 1     12
# 2      5
# Name: User friendly Interface, dtype: int64

# %%
sns.countplot(x='Convenient Payment methods',data=df)
print(df['Convenient Payment methods'].value_counts())
# Out:
# 2    159
# 0     80
# 1     30
# Name: Convenient Payment methods, dtype: int64

# %%
sns.countplot(x='Empathy',data=df)
print(df['Empathy'].value_counts())
# Out:
# 1    194
# 0     42
# 2     18
# 3     15
# Name: Empathy, dtype: int64

# %%
sns.countplot(x='Customer privacy gurantee',data=df)
print(df['Customer privacy gurantee'].value_counts())
# Out:
# 1    185
# 0     58
# 2     26
# Name: Customer privacy gurantee, dtype: int64

# %%
sns.countplot(x='Responsiveness/availability of communication channels',data=df)
print(df['Responsiveness/availability of communication channels'].value_counts())
# Out:
# 1    149
# 0     94
# 3     15
# 2     11
# Name: Responsiveness/availability of communication channels, dtype: int64

# %%
sns.countplot(x='Monetary benefit and discounts',data=df)
print(df['Monetary benefit and discounts'].value_counts())
# Out:
# 2    105
# 0     85
# 4     50
# 3     18
# 1     11
# Name: Monetary benefit and discounts, dtype: int64

# %%
sns.countplot(x='Enjoyment derived',data=df)
print(df['Enjoyment derived'].value_counts())
# Out:
# 2    86
# 4    75
# 0    59
# 3    30
# 1    19
# Name: Enjoyment derived, dtype: int64

# %%
sns.countplot(x='Convenience/flexiblility',data=df)
print(df['Convenience/flexiblility'].value_counts())
# Out:
# 2    146
# 0     78
# 3     33
# 1     12
# Name: Convenience/flexiblility, dtype: int64

# %%
sns.countplot(x='Return and replacement policy',data=df)
print(df['Return and replacement policy'].value_counts())
# Out:
# 2    198
# 0     51
# 1     20
# Name: Return and replacement policy, dtype: int64

# %%
sns.countplot(x='Access to loyalty programs',data=df)
print(df['Access to loyalty programs'].value_counts())
# Out:
# 2    115
# 4     64
# 0     64
# 1     15
# 3     11
# Name: Access to loyalty programs, dtype: int64

# %%
sns.countplot(x='Display of quality information',data=df)
print(df['Display of quality information'].value_counts())
# Out:
# 1    133
# 0     80
# 2     56
# Name: Display of quality information, dtype: int64

# %%
sns.countplot(x='Satisfaction',data=df)
print(df['Satisfaction'].value_counts())
# Out:
# 2    175
# 0     86
# 1      8
# Name: Satisfaction, dtype: int64

# %%
sns.countplot(x='Net Benefit',data=df)
print(df['Net Benefit'].value_counts())
# Out:
# 2    164
# 0     54
# 3     40
# 1     11
# Name: Net Benefit, dtype: int64

# %%
sns.countplot(x='Trust',data=df)
print(df['Trust'].value_counts())
# Out:
# 2    122
# 0    117
# 3     18
# 1      7
# 4      5
# Name: Trust, dtype: int64

# %%
sns.countplot(x='Wide variety of listed product',data=df)
print(df['Wide variety of listed product'].value_counts())
# Out:
# 2    111
# 0     94
# 3     57
# 1      7
# Name: Wide variety of listed product, dtype: int64

# %%
sns.countplot(x='Complete and relevant product information',data=df)
print(df['Complete and relevant product information'].value_counts())
# Out:
# 2    135
# 0     98
# 3     31
# 1      5
# Name: Complete and relevant product information, dtype: int64

# %%
sns.countplot(x='Monetary savings',data=df)
print(df['Monetary savings'].value_counts())
# Out:
# 2    148
# 0     75
# 1     31
# 3     15
# Name: Monetary savings, dtype: int64

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Pincode', 'Shopping years',
#        'Online purchase in the past 1 year', 'Internet access',
#        'Access device', 'Screen size of your mobile device', 'OS of device',
#        'Browser', 'Channel', 'Medium of next visit', 'Explore time',
#        'Preferred payment option', 'Abandon frequency', 'Abandon reason',
#        'Easy to read and understand content', 'Information on similar product',
#        'Complete information on listed seller and product',
#        'All relevant information on listed products',
#        'Ease of navigation in website', 'Loading and processing speed',
#        'User friendly Interface', 'Convenient Payment methods',
#        'Trust for stipulated time', 'Empathy', 'Customer privacy gurantee',
#        'Responsiveness/availability of communication channels',
#        'Monetary benefit and discounts', 'Enjoyment derived',
#        'Convenience/flexiblility', 'Return and replacement policy',
# ...

# %%
sns.countplot(x='Convenience of patronizing',data=df)
print(df['Convenience of patronizing'].value_counts())
# Out:
# 0    138
# 2     77
# 1     54
# Name: Convenience of patronizing, dtype: int64

# %%
sns.countplot(x='Sense of adventure',data=df)
print(df['Sense of adventure'].value_counts())
# Out:
# 0    101
# 4     59
# 2     54
# 1     50
# 3      5
# Name: Sense of adventure, dtype: int64

# %%
sns.countplot(x='Enhancement of social status',data=df)
print(df['Enhancement of social status'].value_counts())
# Out:
# 4    100
# 0     59
# 2     48
# 3     33
# 1     29
# Name: Enhancement of social status, dtype: int64

# %%
sns.countplot(x='Gratification',data=df)
print(df['Gratification'].value_counts())
# Out:
# 4    101
# 2     65
# 0     63
# 1     22
# 3     18
# Name: Gratification, dtype: int64

# %%
sns.countplot(x='Fulfillment of certain roles',data=df)
print(df['Fulfillment of certain roles'].value_counts())
# Out:
# 4    88
# 0    88
# 2    38
# 3    33
# 1    22
# Name: Fulfillment of certain roles, dtype: int64

# %%
sns.countplot(x='Value for money spent',data=df)
print(df['Value for money spent'].value_counts())
# Out:
# 0    149
# 1     82
# 2     38
# Name: Value for money spent, dtype: int64

# %%
sns.countplot(x='Online retailers customer shopped from',data=df)
print(df['Online retailers customer shopped from'].value_counts())
# Out:
# 4    82
# 2    44
# 1    32
# 5    29
# 6    27
# 8    20
# 0    16
# 7    12
# 3     7
# Name: Online retailers customer shopped from, dtype: int64

# %%
sns.countplot(x='Easy to use website/application',data=df)
print(df['Easy to use website/application'].value_counts())
# Out:
# 4    64
# 3    44
# 1    44
# 0    29
# 5    22
# 7    20
# 2    19
# 9    12
# 8     8
# 6     7
# Name: Easy to use website/application, dtype: int64

# %%
sns.countplot(x='visual appeal',data=df)
print(df['visual appeal'].value_counts())
# Out:
# 1    87
# 0    44
# 3    36
# 6    20
# 9    15
# 8    15
# 5    15
# 2    14
# 7    12
# 4    11
# Name: visual appeal, dtype: int64

# %%
sns.countplot(x='Wild variety of product on offer',data=df)
print(df['Wild variety of product on offer'].value_counts())
# Out:
# 1    130
# 0     43
# 4     20
# 7     15
# 6     15
# 2     14
# 3     13
# 5     12
# 8      7
# Name: Wild variety of product on offer, dtype: int64

# %%
sns.countplot(x='Complete, relevant description information of products',data=df)
print(df['Complete, relevant description information of products'].value_counts())
# Out:
# 1     100
# 0      43
# 4      24
# 7      20
# 5      15
# 2      15
# 3      14
# 10     12
# 9      11
# 8       8
# 6       7
# Name: Complete, relevant description information of products, dtype: int64

# %%
sns.countplot(x='Loading time',data=df)
print(df['Loading time'].value_counts())
# Out:
# 0    51
# 7    44
# 5    30
# 2    30
# 1    30
# 6    25
# 4    25
# 3    14
# 9    12
# 8     8
# Name: Loading time, dtype: int64

# %%
sns.countplot(x='Reliability',data=df)
print(df['Reliability'].value_counts())
# Out:
# 0    61
# 1    50
# 3    36
# 6    35
# 5    18
# 8    15
# 7    15
# 2    14
# 4    13
# 9    12
# Name: Reliability, dtype: int64

# %%
sns.countplot(x='Quickness to complete purchase',data=df)
print(df['Quickness to complete purchase'].value_counts())
# Out:
# 0    66
# 3    47
# 1    37
# 2    30
# 8    25
# 5    20
# 6    15
# 4    15
# 7    14
# Name: Quickness to complete purchase, dtype: int64

# %%
sns.countplot(x='Availability of several payment options',data=df)
print(df['Availability of several payment options'].value_counts())
# Out:
# 1     65
# 2     40
# 4     39
# 0     23
# 10    20
# 3     19
# 5     18
# 8     14
# 9     12
# 6     11
# 7      8
# Name: Availability of several payment options, dtype: int64

# %%
sns.countplot(x='Speedy order delivery ',data=df)
print(df['Speedy order delivery '].value_counts())
# Out:
# 0    107
# 1     82
# 3     36
# 4     15
# 2     15
# 5     14
# Name: Speedy order delivery , dtype: int64

# %%
sns.countplot(x='Privacy of customers’ information',data=df)
print(df['Privacy of customers’ information'].value_counts())
# Out:
# 0     71
# 1     54
# 2     25
# 5     24
# 10    18
# 9     15
# 8     15
# 7     15
# 3     14
# 4     11
# 6      7
# Name: Privacy of customers’ information, dtype: int64

# %%
sns.countplot(x='Security of customer financial information',data=df)
print(df['Security of customer financial information'].value_counts())
# Out:
# 0     51
# 4     42
# 8     33
# 5     25
# 1     24
# 6     20
# 7     19
# 10    15
# 9     15
# 2     14
# 3     11
# Name: Security of customer financial information, dtype: int64

# %%
sns.countplot(x='Perceived Trustworthiness',data=df)
print(df['Perceived Trustworthiness'].value_counts())
# Out:
# 0    76
# 5    36
# 6    35
# 1    31
# 7    27
# 2    25
# 8    15
# 4    13
# 3    11
# Name: Perceived Trustworthiness, dtype: int64

# %%
sns.countplot(x='Presence of online assistance through multi-channel',data=df)
print(df['Presence of online assistance through multi-channel'].value_counts())
# Out:
# 3    61
# 0    60
# 1    39
# 6    26
# 8    20
# 5    15
# 2    15
# 4    13
# 9    12
# 7     8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
sns.countplot(x='Longer time to get logged in',data=df)
print(df['Longer time to get logged in'].value_counts())
# Out:
# 0    57
# 8    38
# 1    38
# 7    35
# 2    29
# 9    25
# 5    15
# 6    13
# 3    11
# 4     8
# Name: Longer time to get logged in, dtype: int64

# %%
sns.countplot(x='Longer time in displaying graphics and photos',data=df)
print(df['Longer time in displaying graphics and photos'].value_counts())
# Out:
# 1    60
# 0    39
# 6    35
# 9    34
# 7    25
# 5    19
# 8    15
# 4    15
# 2    14
# 3    13
# Name: Longer time in displaying graphics and photos, dtype: int64

# %%
sns.countplot(x='Late declaration of price',data=df)
print(df['Late declaration of price'].value_counts())
# Out:
# 4    75
# 5    52
# 7    41
# 3    38
# 0    38
# 2    13
# 6     7
# 1     5
# Name: Late declaration of price, dtype: int64

# %%
sns.countplot(x='Longer page loading time',data=df)
print(df['Longer page loading time'].value_counts())
# Out:
# 7     61
# 8     59
# 5     32
# 10    23
# 1     18
# 0     16
# 9     15
# 4     14
# 2     13
# 6     11
# 3      7
# Name: Longer page loading time, dtype: int64

# %%
sns.countplot(x='Limited mode of payment on most products',data=df)
print(df['Limited mode of payment on most products'].value_counts())
# Out:
# 7    87
# 0    62
# 3    31
# 1    29
# 5    25
# 6    15
# 2    13
# 4     7
# Name: Limited mode of payment on most products, dtype: int64

# %%
sns.countplot(x='Longer delivery period',data=df)
print(df['Longer delivery period'].value_counts())
# Out:
# 3    72
# 5    64
# 1    44
# 0    37
# 4    26
# 2    26
# Name: Longer delivery period, dtype: int64

# %%
sns.countplot(x='Change in website/Application design',data=df)
print(df['Change in website/Application design'].value_counts())
# Out:
# 0    96
# 5    63
# 1    45
# 4    30
# 2    20
# 6     8
# 3     7
# Name: Change in website/Application design, dtype: int64

# %%
sns.countplot(x='Frequent disruption when moving from one page to another',data=df)
print(df['Frequent disruption when moving from one page to another'].value_counts())
# Out:
# 0    53
# 4    52
# 7    49
# 6    39
# 2    26
# 1    25
# 5    14
# 3    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
sns.countplot(x='Website efficiency',data=df)
print(df['Website efficiency'].value_counts())
# Out:
# 0    94
# 4    47
# 1    45
# 2    25
# 3    18
# 6    15
# 5    14
# 7    11
# Name: Website efficiency, dtype: int64

# %%
sns.countplot(x='Recommended online retailer',data=df)
print(df['Recommended online retailer'].value_counts())
# Out:
# 0    79
# 1    62
# 6    39
# 3    30
# 5    20
# 2    15
# 4    13
# 7    11
# Name: Recommended online retailer, dtype: int64

# %% [markdown]
# # Describing Dataset

# %%
df.describe()
# Out:
#            Gender         Age        City        Pincode  Shopping years  \
# count  269.000000  269.000000  269.000000     269.000000      269.000000
# mean     0.327138    1.330855    4.494424  220465.747212        2.323420
# std      0.470042    1.183774    3.187687  140524.341051        1.176357
# min      0.000000    0.000000    0.000000  110008.000000        0.000000
# 25%      0.000000    0.000000    2.000000  122018.000000        1.000000
# 50%      0.000000    1.000000    4.000000  201303.000000        3.000000
# 75%      1.000000    2.000000    7.000000  201310.000000        3.000000
# max      1.000000    4.000000   10.000000  560037.000000        4.000000
#
#        Online purchase in the past 1 year  Internet access  Access device  \
# count                          269.000000       269.000000     269.000000
# mean                             3.237918         2.078067       1.501859
# std                              1.739331         0.715919       0.751240
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.iloc[:,:30].describe(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.iloc[:,30:60].describe(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.iloc[:,60:72].describe(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                                                       Gender       Age  \
# Gender                                              1.000000  0.046169
# Age                                                 0.046169  1.000000
# City                                                0.080912  0.113712
# Pincode                                            -0.260365 -0.120704
# Shopping years                                     -0.057096 -0.087847
# ...                                                      ...       ...
# Longer delivery period                              0.060838 -0.156173
# Change in website/Application design               -0.164818 -0.134558
# Frequent disruption when moving from one page t... -0.256638 -0.018825
# Website efficiency                                  0.055663 -0.008582
# Recommended online retailer                        -0.003372 -0.135263
#
#                                                         City   Pincode  \
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.iloc[:,:30].corr(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.iloc[:,30:60].corr(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.iloc[:,60:72].corr(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking outliers

# %%
df.skew()
# Out:
# Gender                                                      0.741028
# Age                                                         0.680987
# City                                                        0.313729
# Pincode                                                     1.748322
# Shopping years                                             -0.276968
#                                                               ...
# Longer delivery period                                     -0.147702
# Change in website/Application design                        0.354163
# Frequent disruption when moving from one page to another   -0.100608
# Website efficiency                                          0.662084
# Recommended online retailer                                 0.583614
# Length: 71, dtype: float64

# %%
df.iloc[:,:30].skew()
# Out:
# Gender                                                   0.741028
# Age                                                      0.680987
# City                                                     0.313729
# Pincode                                                  1.748322
# Shopping years                                          -0.276968
# Online purchase in the past 1 year                      -0.421739
# Internet access                                         -0.361630
# Access device                                           -0.485180
# Screen size of your mobile device                       -1.308503
# OS of device                                            -0.270283
# Browser                                                  1.710244
# Channel                                                 -2.469485
# Medium of next visit                                    -0.041161
# Explore time                                            -0.390691
# ...

# %% [markdown]
# Considering -/+0.5 as the threshold

# %% [raw]
# Gender
# Age
# Pincode
# Screen size of your mobile device
# Browser
# Channel
# Abandon frequency
# Abandon reason
# Easy to read and understand content
# Information on similar product
# User friendly Interface
# Convenient Payment methods
# Empathy
# Responsiveness/availability of communication channels

# %%
df.iloc[:,30:60].skew()
# Out:
# Enjoyment derived                                        -0.165331
# Convenience/flexiblility                                 -0.447632
# Return and replacement policy                            -1.305697
# Access to loyalty programs                                0.026436
# Display of quality information                            0.128003
# Satisfaction                                             -0.704827
# Net Benefit                                              -0.785908
# Trust                                                     0.171700
# Wide variety of listed product                           -0.226594
# Complete and relevant product information                -0.236621
# Monetary savings                                         -0.442062
# Convenience of patronizing                                0.456611
# Sense of adventure                                        0.579282
# Enhancement of social status                             -0.303870
# ...

# %% [raw]
# Return and replacement policy
# Satisfaction
# Net benefit
# Sense of adventure
# Value for money spent
# Visual appeal
# Wild variety of product on offer
# Complete, relevant description information of products
# Quickness to complete purchase
# Availability of several payment options
# Speedy order delivery
# Privacy of customers’ information

# %%
df.iloc[:,60:72].skew()
# Out:
# Presence of online assistance through multi-channel         0.577166
# Longer time to get logged in                                0.131096
# Longer time in displaying graphics and photos               0.167550
# Late declaration of price                                  -0.378929
# Longer page loading time                                   -0.708594
# Limited mode of payment on most products                   -0.086712
# Longer delivery period                                     -0.147702
# Change in website/Application design                        0.354163
# Frequent disruption when moving from one page to another   -0.100608
# Website efficiency                                          0.662084
# Recommended online retailer                                 0.583614
# dtype: float64

# %% [raw]
# Presence of online assistance through multi-channel
# Longer page loading time
# Website efficiency
# Recommended online retailer

# %%
df['Gender'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Pincode'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Screen size of your mobile device'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Browser'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Channel'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Abandon frequency'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Abandon reason'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Easy to read and understand content'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Information on similar product'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Convenient Payment methods'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['User friendly Interface'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Empathy'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Responsiveness/availability of communication channels'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Return and replacement policy'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Satisfaction'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Net Benefit'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Sense of adventure'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Value for money spent'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['visual appeal'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Wild variety of product on offer'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Complete, relevant description information of products'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Availability of several payment options'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Quickness to complete purchase'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Speedy order delivery '].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Privacy of customers’ information'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Presence of online assistance through multi-channel'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Longer page loading time'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Website efficiency'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Recommended online retailer'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([  4,  16,  20,  30,  35,  49,  79,  88,  95, 112, 116, 133, 142,
#         159, 162, 196, 207, 234, 237, 262]),
#  array([11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#         11, 11, 11]))

# %%
df=df[(z<3).all(axis=1)]
df
# Out:
#      Gender  Age  City  Pincode  Shopping years  \
# 0         1    1     2   110009               3
# 1         0    0     2   110030               3
# 2         0    0     4   201308               2
# 3         1    0     6   132001               2
# 5         0    1     9   201308               3
# ..      ...  ...   ...      ...             ...
# 264       0    0    10   173212               0
# 265       0    1     3   201008               0
# 266       0    2     0   560010               1
# 267       0    4    10   173229               1
# 268       0    2     3   201009               1
#
#      Online purchase in the past 1 year  Internet access  Access device  \
# 0                                     2                0              0
# 1                                     3                3              2
# 2                                     3                1              2
# 3                                     5                1              2
# ...

# %% [markdown]
# Percentage Dataloss

# %%
Data_loss=((269-249)/269)*100
Data_loss
# Out:
# 7.434944237918216

# %% [markdown]
# # Transforming dataset

# %%
x=df.drop('Recommended online retailer',axis=1)
y=df['Recommended online retailer']

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')
x
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# array([[ 1.42708982, -0.15346873, -0.80787619, ...,  0.13781299,
#         -1.46220623, -1.14044446],
#        [-0.70072674, -1.37612872, -0.80787619, ..., -1.22491078,
#          0.32605469, -0.08484615],
#        [-0.70072674, -1.37612872, -0.07892817, ...,  1.13659767,
#          1.00486503, -1.14044446],
#        ...,
#        [-0.70072674,  0.65271935, -1.83632223, ...,  1.37500012,
#          1.31880971, -1.14044446],
#        [-0.70072674,  1.77587749,  1.52386542, ..., -1.22491078,
#          0.67516569,  1.33556796],
#        [-0.70072674,  0.65271935, -0.42210019, ..., -1.22491078,
#         -1.46220623, -1.14044446]])

# %% [markdown]
# # Scaling Dataset

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.42708982, -0.15346873, -0.80787619, ...,  0.13781299,
#         -1.46220623, -1.14044446],
#        [-0.70072674, -1.37612872, -0.80787619, ..., -1.22491078,
#          0.32605469, -0.08484615],
#        [-0.70072674, -1.37612872, -0.07892817, ...,  1.13659767,
#          1.00486503, -1.14044446],
#        ...,
#        [-0.70072674,  0.65271935, -1.83632223, ...,  1.37500012,
#          1.31880971, -1.14044446],
#        [-0.70072674,  1.77587749,  1.52386542, ..., -1.22491078,
#          0.67516569,  1.33556796],
#        [-0.70072674,  0.65271935, -0.42210019, ..., -1.22491078,
#         -1.46220623, -1.14044446]])
